# %% [markdown]
# ![Séries de TV](caminho/para/sua/imagem.jpg![ series.jpg](data:image/jpeg;base64,...))
#
# # Programa de Cadastro de Séries de TV
#
# Este programa permite que o usuário cadastre as séries de TV que está assistindo, juntamente com a temporada atual.
# Além disso, o usuário pode adicionar notas críticas para as séries cadastradas.
# O programa interage com o usuário, fornecendo um menu de opções para adicionar novas séries, adicionar notas críticas, visualizar todas as séries cadastradas ou sair do programa.
#
# ## Funcionalidades:
# 1. Cadastro de séries e temporadas.
# 2. Adição de notas críticas para séries cadastradas.
# 3. Visualização de todas as séries cadastradas.
# 4. Saída do programa.
#
# ## Instruções:
# 1. Ao iniciar o programa, será solicitado o nome, idade e país do usuário, com uma mensagem de boas-vindas.
# 2. O usuário pode escolher adicionar uma nova série, adicionar uma nota crítica, visualizar todas as séries ou sair do programa.

# %%
def boas_vindas():
    nome = input("Qual é o seu nome? ")
    idade = input("Qual é a sua idade? ")
    pais = input("Qual é o seu país? ")
    print(f"\nBem-vindo(a), {nome} de {idade} anos, do {pais}!\n")
    return nome

def adicionar_serie(series):
    serie = input("Qual série você está assistindo? ")
    temporada = input("Qual temporada você está atualmente? ")
    series[serie] = {"temporada": temporada, "nota_critica": ""}
    print(f"Série '{serie}' adicionada com sucesso!\n")

def adicionar_nota_critica(series):
    serie = input("Para qual série você quer adicionar uma nota crítica? ")
    if serie in series:
        nota_critica = input("Digite sua nota crítica para essa série: ")
        series[serie]["nota_critica"] = nota_critica
        print(f"Nota crítica para a série '{serie}' adicionada com sucesso!\n")
    else:
        print(f"Série '{serie}' não encontrada no cadastro.\n")

def mostrar_series(series):
    if not series:
        print("Nenhuma série cadastrada.\n")
    else:
        for serie, detalhes in series.items():
            print(f"Série: {serie}, Temporada: {detalhes['temporada']}, Nota Crítica: {detalhes['nota_critica']}\n")

def main():
    series = {}
    nome = boas_vindas()

    while True:
        print("O que você gostaria de fazer?")
        print("1. Adicionar uma nova série")
        print("2. Adicionar uma nota crítica para uma série")
        print("3. Mostrar todas as séries cadastradas")
        print("4. Sair do programa")

        escolha = input("Digite o número da sua escolha: ")

        if escolha == "1":
            adicionar_serie(series)
        elif escolha == "2":
            adicionar_nota_critica(series)
        elif escolha == "3":
            mostrar_series(series)
        elif escolha == "4":
            print(f"Até logo, {nome}!")
            break
        else:
            print("Escolha inválida. Tente novamente.\n")

if __name__ == "__main__":
    main()
# Out:
# Qual é o seu nome? Lenon
# Qual é a sua idade? 30
# Qual é o seu país? Brasil
#
# Bem-vindo(a), Lenon de 30 anos, do Brasil!
#
# O que você gostaria de fazer?
# 1. Adicionar uma nova série
# 2. Adicionar uma nota crítica para uma série
# 3. Mostrar todas as séries cadastradas
# 4. Sair do programa
# Digite o número da sua escolha: 1
# Qual série você está assistindo? House of the Dragons
# Qual temporada você está atualmente? 2
# Série 'House of the Dragons' adicionada com sucesso!
#
# O que você gostaria de fazer?
# 1. Adicionar uma nova série
# 2. Adicionar uma nota crítica para uma série
# 3. Mostrar todas as séries cadastradas
# 4. Sair do programa
# Digite o número da sua escolha: 1
# Qual série você está assistindo? The boys
# Qual temporada você está atualmente? 4
# Série 'The boys' adicionada com sucesso!
#
# O que você gostaria de fazer?
# 1. Adicionar uma nova série
# 2. Adicionar uma nota crítica para uma série
# 3. Mostrar todas as séries cadastradas
# ...
